# %% [markdown]
# ![DLI_Header.png](data:image/png;base64,...)

# %% [markdown]
# # 3. Convolutional Neural Networks

# %% [markdown]
# In the previous section, we built and trained a simple model to classify ASL images. The model was able to learn how to correctly classify the training dataset with very high accuracy, but, it did not perform nearly as well on validation dataset. This behavior of not generalizing well to non-training data is called [overfitting](https://scikit-learn.org/stable/auto_examples/model_selection/plot_underfitting_overfitting.html), and in this section, we will introduce a popular kind of model called a [convolutional neural network](https://towardsdatascience.com/a-comprehensive-guide-to-convolutional-neural-networks-the-eli5-way-3bd2b1164a53) that is especially good for reading images and classifying them.

# %% [markdown]
# ## 3.1 Objectives

# %% [markdown]
# * Prep data specifically for a CNN
# * Create a more sophisticated CNN model, understanding a greater variety of model layers
# * Train a CNN model and observe its performance

# %%
import torch.nn as nn
import pandas as pd
import torch
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms.v2 as transforms
import torchvision.transforms.functional as F
import torchvision.io as tv_io

from sklearn.metrics import confusion_matrix
import seaborn as sns  # 히트맵을 그릴 때 사용
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## 3.2 Loading and Preparing the Data

# %% [markdown]
# ### 3.2.1 Preparing Images

# %% [markdown]
# Let's begin by loading our DataFrames like we did in the previous lab:

# %%
train_df = pd.read_csv("asl_data/sign_mnist_train.csv")
valid_df = pd.read_csv("asl_data/sign_mnist_valid.csv")

# %%
train_df.shape, valid_df.shape
# Out:
# ((27455, 785), (7172, 785))

# %% [markdown]
# This ASL data is already flattened.

# %%
sample_df = train_df.head().copy()  # Grab the top 5 rows
sample_y = sample_df.pop('label')
sample_x = sample_df.values

sample_x, sample_y
# Out:
# (array([[107, 118, 127, ..., 204, 203, 202],
#         [155, 157, 156, ..., 103, 135, 149],
#         [187, 188, 188, ..., 195, 194, 195],
#         [211, 211, 212, ..., 222, 229, 163],
#         [164, 167, 170, ..., 163, 164, 179]], dtype=int64),
#  0     3
#  1     6
#  2     2
#  3     2
#  4    12
#  Name: label, dtype: int64)

# %%
sample_x.shape, sample_y.shape
# Out:
# ((5, 784), (5,))

# %%
sample_df
# Out:
#    pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0     107     118     127     134     139     143     146     150     153
# 1     155     157     156     156     156     157     156     158     158
# 2     187     188     188     187     187     186     187     188     187
# 3     211     211     212     212     211     210     211     210     210
# 4     164     167     170     172     176     179     180     184     185
#
#    pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0      156  ...       207       207       207       207       206       206
# 1      157  ...        69       149       128        87        94       163
# 2      186  ...       202       201       200       199       198       199
# 3      211  ...       235       234       233       231       230       226
# 4      186  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# 0       206       204       203       202
# 1       175       103       135       149
# 2       198       195       194       195
# 3       225       222       229       163
# 4       157       163       164       179
#
# [5 rows x 784 columns]

# %% [markdown]
# In this format, we don't have all the information about which pixels are near each other. Because of this, we can't apply convolutions that will detect features. Let's [reshape](https://numpy.org/doc/stable/reference/generated/numpy.reshape.html) our dataset so that they are in a 28x28 pixel format. This will allow our convolutions to associate groups of pixels and detect important features.
#
# Note that for the first convolutional layer of our model, we need to have not only the height and width of the image, but also the number of [color channels](https://www.photoshopessentials.com/essentials/rgb/). Our images are grayscale, so we'll just have 1 channel.
#
# That means that we need to convert the current shape `(5, 784)` to `(5, 1, 28, 28)`. With [NumPy](https://numpy.org/doc/stable/index.html) arrays, we can pass a `-1` for any dimension we wish to remain the same.

# %%
# sample_x.shape : (5, 784)

IMG_HEIGHT = 28
IMG_WIDTH = 28
IMG_CHS = 1
N_CLASSES = 24

sample_x = sample_x.reshape(-1, IMG_CHS, IMG_HEIGHT, IMG_WIDTH)  # x = x.unsqueeze(1)  # (5, 28, 28) → (5, 1, 28, 28)
sample_x.shape
# Out:
# (5, 1, 28, 28)

# %% [markdown]
# ### 3.2.2 Create a Dataset

# %% [markdown]
# Let's add the steps above into our `MyDataset` class.

# %%
class MyDataset(Dataset):
    def __init__(self, base_df):
        x_df = base_df.copy()  # Some operations below are in-place
        y_df = x_df.pop('label')
        x_df = x_df.values / 255  # Normalize values from 0 to 1
        x_df = x_df.reshape(-1, 1, 28, 28)
        self.xs = torch.tensor(x_df).float().to(device)
        self.ys = torch.tensor(y_df).to(device)

    def __getitem__(self, idx):
        x = self.xs[idx]
        y = self.ys[idx]
        return x, y

    def __len__(self):
        return len(self.xs)

# x_df = base_df.copy()
# Pandas에서 DataFrame을 슬라이싱하거나 인덱싱하면 원본 DataFrame의 뷰가 반환됩니다.
# 뷰를 수정하면 원본 DataFrame도 수정됩니다. .copy() 메서드를 사용하여 복사본을 만들면
# 원본 DataFrame에 영향을 주지 않고 복사본을 수정할 수 있음

# %% [markdown]
# ### 3.2.3 Create a DataLoader

# %% [markdown]
# Next, let's create the DataLoader from the Dataset

# %% [markdown]
# One of these function calls is missing the `shuffle=True` argument. Can you remember which one it is and add it back in?

# %%
BATCH_SIZE = 32

train_data = MyDataset(train_df)
train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
train_N = len(train_loader.dataset)

valid_data = MyDataset(valid_df)
valid_loader = DataLoader(valid_data, batch_size=BATCH_SIZE)
valid_N = len(valid_loader.dataset)

train_N, valid_N
# Out:
# (27455, 7172)

# %%
iter_train_N = len(train_loader) # 전체 train data의 수를 batch_size로 나눈 값 : 27455 / 32
iter_valid_N = len(valid_loader)
iter_train_N, iter_valid_N
# Out:
# (858, 225)

# %%
train_data.__getitem__(0), train_data.__len__(), train_data.__getitem__(0)[0].shape
# Out:
# ((tensor([[[0.4196, 0.4627, 0.4980, 0.5255, 0.5451, 0.5608, 0.5725, 0.5882,
#             0.6000, 0.6118, 0.6196, 0.6275, 0.6392, 0.6471, 0.6235, 0.6510,
#             0.6588, 0.6667, 0.6667, 0.6706, 0.6706, 0.6706, 0.6745, 0.6706,
#             0.6706, 0.6667, 0.6667, 0.6627],
#            [0.4353, 0.4745, 0.5059, 0.5294, 0.5529, 0.5647, 0.5804, 0.5922,
#             0.6039, 0.6157, 0.6275, 0.6392, 0.6431, 0.6667, 0.4667, 0.5961,
#             0.6706, 0.6706, 0.6667, 0.6706, 0.6745, 0.6745, 0.6745, 0.6745,
#             0.6745, 0.6706, 0.6706, 0.6667],
#            [0.4431, 0.4824, 0.5137, 0.5373, 0.5569, 0.5686, 0.5882, 0.5961,
#             0.6078, 0.6196, 0.6314, 0.6392, 0.6431, 0.6745, 0.4118, 0.5569,
#             0.6667, 0.6706, 0.6706, 0.6706, 0.6745, 0.6745, 0.6784, 0.6784,
#             0.6745, 0.6706, 0.6706, 0.6706],
#            [0.4549, 0.4902, 0.5216, 0.5451, 0.5608, 0.5725, 0.5922, 0.6000,
#             0.6118, 0.6235, 0.6353, 0.6392, 0.6549, 0.6549, 0.3725, 0.5647,
#             0.6706, 0.6745, 0.6745, 0.6745, 0.6745, 0.6745, 0.6784, 0.6784,
#             0.6784, 0.6745, 0.6745, 0.6706],
#            [0.4588, 0.4941, 0.5255, 0.5490, 0.5686, 0.5843, 0.6000, 0.6118,
#             0.6196, 0.6314, 0.6392, 0.6431, 0.6863, 0.6118, 0.3412, 0.6039,
#             0.6745, 0.6784, 0.6784, 0.6784, 0.6784, 0.6784, 0.6824, 0.6824,
#             0.6824, 0.6784, 0.6745, 0.6745],
#            [0.4667, 0.5020, 0.5333, 0.5569, 0.5725, 0.5882, 0.6000, 0.6118,
#             0.6235, 0.6392, 0.6471, 0.6431, 0.7216, 0.5804, 0.3490, 0.6431,
#             0.6745, 0.6824, 0.6824, 0.6824, 0.6824, 0.6863, 0.6863, 0.6824,
#             0.6863, 0.6824, 0.6784, 0.6784],
#            [0.4784, 0.5098, 0.5412, 0.5608, 0.5765, 0.5882, 0.6039, 0.6196,
#             0.6353, 0.6471, 0.6510, 0.6745, 0.7098, 0.5020, 0.3686, 0.6667,
#             0.6784, 0.6863, 0.6824, 0.6863, 0.6902, 0.6941, 0.6941, 0.6941,
#             0.6941, 0.6863, 0.6863, 0.6824],
#            [0.4784, 0.5176, 0.5451, 0.5686, 0.5843, 0.5961, 0.6118, 0.6275,
#             0.6392, 0.6471, 0.6510, 0.7098, 0.6745, 0.4039, 0.4431, 0.6863,
#             0.6902, 0.6980, 0.6980, 0.7020, 0.7020, 0.7020, 0.7020, 0.6980,
#             0.7020, 0.6941, 0.6863, 0.6824],
#            [0.4902, 0.5255, 0.5529, 0.5765, 0.5882, 0.6000, 0.6157, 0.6314,
#             0.6431, 0.6549, 0.6588, 0.7216, 0.7020, 0.4549, 0.4941, 0.6471,
#             0.6902, 0.7020, 0.7059, 0.7059, 0.7098, 0.7059, 0.7059, 0.7059,
#             0.7020, 0.6980, 0.6941, 0.6902],
#            [0.5020, 0.5294, 0.5569, 0.5804, 0.5961, 0.6039, 0.6196, 0.6353,
#             0.6471, 0.6588, 0.6667, 0.7333, 0.7059, 0.6118, 0.6314, 0.4863,
#             0.5608, 0.7020, 0.6980, 0.6980, 0.7098, 0.7137, 0.7098, 0.7059,
#             0.7098, 0.7059, 0.7020, 0.7020],
#            [0.5059, 0.5333, 0.5647, 0.5882, 0.6000, 0.6078, 0.6235, 0.6392,
#             0.6510, 0.6627, 0.6745, 0.7333, 0.7216, 0.6000, 0.4000, 0.4588,
#             0.4314, 0.6863, 0.6627, 0.6039, 0.7137, 0.7176, 0.7176, 0.7137,
#             0.7137, 0.7098, 0.7098, 0.7020],
#            [0.5137, 0.5412, 0.5686, 0.5882, 0.6078, 0.6157, 0.6314, 0.6471,
#             0.6588, 0.6824, 0.7451, 0.7412, 0.6863, 0.5725, 0.3686, 0.3804,
#             0.4431, 0.5922, 0.6196, 0.5059, 0.7216, 0.7216, 0.7216, 0.7216,
#             0.7176, 0.7176, 0.7137, 0.7059],
#            [0.5137, 0.5451, 0.5725, 0.5922, 0.6078, 0.6235, 0.6392, 0.6549,
#             0.6863, 0.7137, 0.7020, 0.6706, 0.6235, 0.4471, 0.4000, 0.3490,
#             0.4745, 0.5333, 0.5333, 0.3765, 0.6745, 0.7294, 0.7294, 0.7255,
#             0.7255, 0.7216, 0.7137, 0.7098],
#            [0.5137, 0.5490, 0.5765, 0.6039, 0.6157, 0.6275, 0.6431, 0.7020,
#             0.7294, 0.7490, 0.7333, 0.7059, 0.6157, 0.3922, 0.3451, 0.3294,
#             0.4235, 0.4353, 0.4941, 0.3529, 0.4706, 0.7294, 0.7333, 0.7333,
#             0.7294, 0.7255, 0.7216, 0.7137],
#            [0.5216, 0.5529, 0.5843, 0.6078, 0.6196, 0.6275, 0.6824, 0.7882,
#             0.7412, 0.6471, 0.5922, 0.5608, 0.5725, 0.4706, 0.3412, 0.3059,
#             0.3412, 0.2980, 0.4235, 0.3843, 0.3765, 0.7098, 0.7373, 0.7333,
#             0.7294, 0.7294, 0.7255, 0.7176],
#            [0.5216, 0.5529, 0.5882, 0.6118, 0.6275, 0.6314, 0.7020, 0.7725,
#             0.6824, 0.5294, 0.3882, 0.2824, 0.3725, 0.5255, 0.3804, 0.2824,
#             0.2902, 0.2667, 0.4549, 0.4118, 0.4235, 0.7333, 0.7412, 0.7333,
#             0.7333, 0.7294, 0.7294, 0.7255],
#            [0.5255, 0.5608, 0.5922, 0.6118, 0.6314, 0.6392, 0.7020, 0.7608,
#             0.6118, 0.4314, 0.2902, 0.1647, 0.2039, 0.5451, 0.3686, 0.2627,
#             0.2941, 0.2941, 0.4627, 0.4157, 0.5059, 0.7412, 0.7490, 0.7451,
#             0.7373, 0.7373, 0.7333, 0.7294],
#            [0.5294, 0.5647, 0.5961, 0.6196, 0.6392, 0.6392, 0.6941, 0.7569,
#             0.6314, 0.4784, 0.3294, 0.1686, 0.2784, 0.5255, 0.3176, 0.2235,
#             0.2784, 0.3451, 0.4392, 0.3843, 0.6157, 0.7569, 0.7569, 0.7529,
#             0.7451, 0.7451, 0.7412, 0.7373],
#            [0.5333, 0.5647, 0.5961, 0.6196, 0.6353, 0.6392, 0.6902, 0.7529,
#             0.6431, 0.5020, 0.3843, 0.2431, 0.2353, 0.3922, 0.2784, 0.2980,
#             0.3765, 0.3961, 0.4118, 0.3725, 0.6824, 0.7647, 0.7608, 0.7608,
#             0.7608, 0.7569, 0.7490, 0.7451],
#            [0.5373, 0.5686, 0.5961, 0.6235, 0.6431, 0.6471, 0.6980, 0.7490,
#             0.6431, 0.5294, 0.4431, 0.3216, 0.2314, 0.3412, 0.3843, 0.4353,
#             0.4706, 0.4235, 0.3804, 0.4235, 0.7451, 0.7686, 0.7647, 0.7647,
#             0.7608, 0.7569, 0.7569, 0.7529],
#            [0.5451, 0.5725, 0.6039, 0.6275, 0.6431, 0.6471, 0.6863, 0.7294,
#             0.6392, 0.5451, 0.4392, 0.3333, 0.2627, 0.4000, 0.4941, 0.5216,
#             0.4941, 0.4118, 0.4078, 0.6902, 0.7725, 0.7765, 0.7725, 0.7686,
#             0.7647, 0.7647, 0.7608, 0.7569],
#            [0.5412, 0.5765, 0.6078, 0.6314, 0.6471, 0.6549, 0.6745, 0.7294,
#             0.6392, 0.5373, 0.4196, 0.3412, 0.2980, 0.4157, 0.4784, 0.4902,
#             0.4588, 0.3765, 0.6118, 0.7804, 0.7804, 0.7843, 0.7765, 0.7686,
#             0.7686, 0.7647, 0.7647, 0.7608],
#            [0.5451, 0.5804, 0.6118, 0.6392, 0.6510, 0.6588, 0.6745, 0.7059,
#             0.6196, 0.5137, 0.4235, 0.3882, 0.3373, 0.4235, 0.4627, 0.4549,
#             0.4039, 0.4196, 0.7490, 0.7922, 0.7882, 0.7843, 0.7843, 0.7843,
#             0.7804, 0.7725, 0.7765, 0.7686],
#            [0.5490, 0.5843, 0.6157, 0.6431, 0.6588, 0.6549, 0.6941, 0.6980,
#             0.6078, 0.5137, 0.4627, 0.4118, 0.3412, 0.3922, 0.4157, 0.3922,
#             0.3765, 0.6431, 0.7922, 0.7922, 0.7922, 0.7922, 0.7922, 0.7882,
#             0.7843, 0.7804, 0.7804, 0.7765],
#            [0.5490, 0.5882, 0.6157, 0.6471, 0.6549, 0.6667, 0.7098, 0.6863,
#             0.5961, 0.5098, 0.4510, 0.3843, 0.3216, 0.3333, 0.3529, 0.3882,
#             0.6471, 0.7922, 0.7961, 0.8000, 0.7961, 0.7961, 0.7922, 0.7922,
#             0.7882, 0.7882, 0.7843, 0.7843],
#            [0.5569, 0.5882, 0.6235, 0.6471, 0.6667, 0.7490, 0.6784, 0.6157,
#             0.5647, 0.4667, 0.3804, 0.3294, 0.3098, 0.3098, 0.3569, 0.6745,
#             0.7922, 0.7961, 0.7961, 0.8039, 0.8000, 0.8000, 0.8000, 0.7961,
#             0.7922, 0.7922, 0.7882, 0.7843],
#            [0.5569, 0.5922, 0.6275, 0.6471, 0.7373, 0.7451, 0.7333, 0.5882,
#             0.4667, 0.4275, 0.3333, 0.3098, 0.3098, 0.3059, 0.5373, 0.7961,
#             0.8039, 0.8078, 0.8078, 0.8118, 0.8118, 0.8078, 0.8078, 0.8000,
#             0.8039, 0.8000, 0.7961, 0.7922],
#            [0.5569, 0.5922, 0.6275, 0.6745, 0.7686, 0.7373, 0.7373, 0.7451,
#             0.5294, 0.3765, 0.3373, 0.3020, 0.3020, 0.3098, 0.6902, 0.8039,
#             0.8118, 0.8118, 0.8118, 0.8118, 0.8118, 0.8118, 0.8078, 0.8078,
#             0.8078, 0.8000, 0.7961, 0.7922]]], device='cuda:0'),
#   tensor(3, device='cuda:0')),
#  27455,
#  torch.Size([1, 28, 28]))

# %%
train_data.__len__(), valid_data.__len__()
# Out:
# (27455, 7172)

# %% [markdown]
# Let's grab a batch from the DataLoader to make sure it works.

# %%
batch = next(iter(train_loader))
batch, type(batch), len(batch[0])
# Out:
# ([tensor([[[[0.7686, 0.7686, 0.7725,  ..., 0.6824, 0.6784, 0.6706],
#             [0.7765, 0.7725, 0.7804,  ..., 0.6902, 0.6863, 0.6745],
#             [0.7804, 0.7804, 0.7843,  ..., 0.7020, 0.6902, 0.6824],
#             ...,
#             [0.4392, 0.4510, 0.4549,  ..., 0.1137, 0.1647, 0.0863],
#             [0.4392, 0.4392, 0.4314,  ..., 0.0980, 0.1451, 0.0588],
#             [0.4471, 0.4392, 0.4314,  ..., 0.0941, 0.1333, 0.0549]]],
#
#
#           [[[0.7804, 0.7922, 0.8039,  ..., 0.7725, 0.7647, 0.7569],
#             [0.7922, 0.8039, 0.8118,  ..., 0.7804, 0.7725, 0.7725],
#             [0.8000, 0.8078, 0.8157,  ..., 0.7882, 0.7843, 0.7765],
#             ...,
#             [0.5882, 0.4549, 0.4510,  ..., 0.9333, 0.9255, 0.9216],
#             [0.4824, 0.4392, 0.4353,  ..., 0.9294, 0.9216, 0.9176],
#             [0.4745, 0.4314, 0.4196,  ..., 0.9255, 0.9255, 0.9176]]],
#
#
#           [[[0.6314, 0.6471, 0.6471,  ..., 0.6667, 0.6588, 0.6588],
#             [0.6392, 0.6471, 0.6510,  ..., 0.6706, 0.6627, 0.6627],
#             [0.6471, 0.6510, 0.6627,  ..., 0.6745, 0.6745, 0.6706],
#             ...,
#             [0.7569, 0.7647, 0.7686,  ..., 0.8000, 0.7922, 0.7922],
#             [0.7569, 0.7608, 0.7686,  ..., 0.8000, 0.8000, 0.8000],
#             [0.7529, 0.7569, 0.7686,  ..., 0.8039, 0.8039, 0.8039]]],
#
#
#           ...,
#
#
#           [[[0.6980, 0.7098, 0.7216,  ..., 0.7725, 0.7725, 0.7647],
#             [0.7020, 0.7176, 0.7294,  ..., 0.7765, 0.7725, 0.7686],
#             [0.7059, 0.7216, 0.7294,  ..., 0.7765, 0.7725, 0.7765],
#             ...,
#             [0.5294, 0.5255, 0.5255,  ..., 0.4706, 0.4706, 0.7804],
#             [0.5294, 0.5255, 0.5255,  ..., 0.4392, 0.7961, 0.9333],
#             [0.5294, 0.5294, 0.5333,  ..., 0.7020, 0.9686, 0.8588]]],
#
#
#           [[[0.7608, 0.7608, 0.7608,  ..., 0.3804, 0.6510, 0.7686],
#             [0.7686, 0.7686, 0.7686,  ..., 0.2667, 0.6431, 0.7608],
#             [0.7765, 0.7765, 0.7804,  ..., 0.3216, 0.7137, 0.7333],
#             ...,
#             [0.4078, 0.4118, 0.4157,  ..., 0.6627, 0.7216, 0.8235],
#             [0.4000, 0.4039, 0.4118,  ..., 0.8157, 0.6627, 0.6863],
#             [0.4000, 0.4000, 0.4078,  ..., 0.7529, 0.7765, 0.6118]]],
#
#
#           [[[0.5961, 0.6196, 0.6392,  ..., 0.6980, 0.6941, 0.6824],
#             [0.6000, 0.6235, 0.6431,  ..., 0.7059, 0.6980, 0.6863],
#             [0.6039, 0.6275, 0.6471,  ..., 0.7137, 0.7059, 0.7020],
#             ...,
#             [0.6235, 0.6510, 0.6784,  ..., 0.7804, 0.7725, 0.7686],
#             [0.6157, 0.6471, 0.6784,  ..., 0.7804, 0.7765, 0.7686],
#             [0.6118, 0.6431, 0.6745,  ..., 0.7765, 0.7686, 0.7647]]]],
#          device='cuda:0'),
#   tensor([12, 23, 12,  6, 23,  6, 16, 18,  3,  7, 13, 17, 16, 23, 16,  6, 13, 20,
#            8,  8,  5, 15,  7,  4, 12,  7, 18, 22, 17, 11, 16, 12],
#          device='cuda:0')],
#  list,
#  32)

# %% [markdown]
# It looks different, but let's check the `shape`s to be sure.

# %%
batch[0].shape
# Out:
# torch.Size([32, 1, 28, 28])

# %%
batch[1].shape
# Out:
# torch.Size([32])

# %%
for x, y in train_loader:
    print(x.shape, y.shape)
    break
# Out:
# torch.Size([32, 1, 28, 28]) torch.Size([32])

# %% [markdown]
# ## 3.3 Creating a Convolutional Model

# %% [markdown]
# These days, many data scientists start their projects by borrowing model properties from a similar project. Assuming the problem is not totally unique, there's a great chance that people have created models that will perform well which are posted in online repositories like [TensorFlow Hub](https://www.tensorflow.org/hub) and the [NGC Catalog](https://ngc.nvidia.com/catalog/models). Today, we'll provide a model that will work well for this problem.
#
# ![cnn.png](data:image/png;base64,...)
#
# We covered many of the different kinds of layers in the lecture, and we will go over them all here with links to their documentation. When in doubt, read the official documentation (or ask [Stack Overflow](https://stackoverflow.com/)).

# %%
n_classes = 24
kernel_size = 3
flattened_img_size = 75 * 3 * 3

# 3개의 입력 채널, 64개의 출력 채널, 3x3 커널, stride 1, padding 1을 사용하는 Conv2d 레이어 생성
# example :
# conv_layer = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, stride=1, padding=1)
# in_channels (int): 입력 이미지의 채널 수. 예를 들어, 흑백 이미지는 1개의 채널, RGB 이미지는 3개의 채널을 가짐.
# out_channels (int): 컨볼루션 연산 후 출력되는 채널 수로 필터의 개수와 같습니다.

'''
model = nn.Sequential(
    # First convolution
    nn.Conv2d(IMG_CHS, 25, kernel_size, stride=1, padding=1),  # 25 x 28 x 28 -> ((28-3+2*1)/1)+1 = 28
    nn.BatchNorm2d(25),
    nn.ReLU(),
    nn.MaxPool2d(2, stride=2),  # 25 x 14 x 14  -> ((28-2)/2)+1 = 14

    # Second convolution
    nn.Conv2d(25, 50, kernel_size, stride=1, padding=1),  # 50 x 14 x 14  -> ((14-3+2*1)/1)+1 = 14
    nn.BatchNorm2d(50),
    nn.ReLU(),
    nn.Dropout(.2),
    nn.MaxPool2d(2, stride=2),  # 50 x 7 x 7  -> ((14-2)/2)+1 = 7

    # Third convolution
    nn.Conv2d(50, 75, kernel_size, stride=1, padding=1),  # 75 x 7 x 7  -> ((7-3+2*1)/1)+1 = 7
    nn.BatchNorm2d(75),
    nn.ReLU(),
    nn.MaxPool2d(2, stride=2),  # 75 x 3 x 3   -> ((7-2)/2)+1 = 3.5 = 3

    # Flatten to Dense
    nn.Flatten(),
    
    # LazyLinear로 변경
    # nn.LazyLinear(512),
    nn.Linear(flattened_img_size, 512),

    nn.Dropout(.3),
    nn.ReLU(),
    nn.Linear(512, n_classes)
)
model
'''
# Out:
# '\nmodel = nn.Sequential(\n    # First convolution\n    nn.Conv2d(IMG_CHS, 25, kernel_size, stride=1, padding=1),  # 25 x 28 x 28 -> ((28-3+2*1)/1)+1 = 28\n    nn.BatchNorm2d(25),\n    nn.ReLU(),\n    nn.MaxPool2d(2, stride=2),  # 25 x 14 x 14  -> ((28-2)/2)+1 = 14\n\n    # Second convolution\n    nn.Conv2d(25, 50, kernel_size, stride=1, padding=1),  # 50 x 14 x 14  -> ((14-3+2*1)/1)+1 = 14\n    nn.BatchNorm2d(50),\n    nn.ReLU(),\n    nn.Dropout(.2),\n    nn.MaxPool2d(2, stride=2),  # 50 x 7 x 7  -> ((14-2)/2)+1 = 7\n\n    # Third convolution\n    nn.Conv2d(50, 75, kernel_size, stride=1, padding=1),  # 75 x 7 x 7  -> ((7-3+2*1)/1)+1 = 7\n    nn.BatchNorm2d(75),\n    nn.ReLU(),\n    nn.MaxPool2d(2, stride=2),  # 75 x 3 x 3   -> ((7-2)/2)+1 = 3.5 = 3\n\n    # Flatten to Dense\n    nn.Flatten(),\n    \n    # LazyLinear로 변경\n    # nn.LazyLinear(512),\n    nn.Linear(flattened_img_size, 512),\n\n    nn.Dropout(.3),\n    nn.ReLU(),\n    nn.Linear(512, n_classes)\n)\nmodel\n'

# %%
class MyConvBlock(nn.Module):
    def __init__(self, in_ch, out_ch, dropout_p):
        kernel_size = 3
        super().__init__()

        self.model = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size, stride=1, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(),
            nn.Dropout(dropout_p),
            nn.MaxPool2d(2, stride=2)
        )

    def forward(self, x):
        return self.model(x)

# %%
flattened_img_size = 75 * 3 * 3

# Input 1 x 28 x 28
base_model = nn.Sequential(
    MyConvBlock(IMG_CHS, 25, 0), # 25 x 14 x 14
    MyConvBlock(25, 50, 0.2), # 50 x 7 x 7
    MyConvBlock(50, 75, 0),  # 75 x 3 x 3
    # Flatten to Dense Layers
    nn.Flatten(),
    nn.Linear(flattened_img_size, 512),
    nn.Dropout(.3),
    nn.ReLU(),
    nn.Linear(512, N_CLASSES)
)

# %% [markdown]
# ### 3.3.1 [Conv2D](https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html)

# %% [markdown]
# ![conv2d.png](data:image/png;base64,...)
#
# These are our 2D convolutional layers. Small kernels will go over the input image and detect features that are important for classification. Earlier convolutions in the model will detect simple features such as lines. Later convolutions will detect more complex features. Let's look at our first Conv2D layer:
# ```Python
# nn.Conv2d(IMG_CHS, 25, kernel_size, stride=1, padding=1)
# ```
# 25 refers to the number of filters that will be learned. Even though `kernel_size = 3`, PyTorch will assume we want 3 x 3 filters. Stride refer to the step size that the filter will take as it passes over the image. Padding refers to whether the output image that's created from the filter will match the size of the input image.

# %% [markdown]
# ### 3.3.2 [BatchNormalization](https://pytorch.org/docs/stable/generated/torch.nn.BatchNorm2d.html)

# %% [markdown]
# Like normalizing our inputs, batch normalization scales the values in the hidden layers to improve training. [Read more about it in detail here](https://blog.paperspace.com/busting-the-myths-about-batch-normalization/).
#
# There is a debate on best where to put the batch normalization layer. [This Stack Overflow post](https://stackoverflow.com/questions/39691902/ordering-of-batch-normalization-and-dropout) compiles many perspectives.

# %% [markdown]
# ### 3.3.3 [MaxPool2D](https://pytorch.org/docs/stable/generated/torch.nn.MaxPool2d.html)

# %% [markdown]
# ![maxpool2d.png](data:image/png;base64,...)
# Max pooling takes an image and essentially shrinks it to a lower resolution. It does this to help the model be robust to translation (objects moving side to side), and also makes our model faster.

# %% [markdown]
# ### 3.3.4 [Dropout](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html)

# %% [markdown]
# ![dropout.png](data:image/png;base64,...)
# Dropout is a technique for preventing overfitting. Dropout randomly selects a subset of neurons and turns them off, so that they do not participate in forward or backward propagation in that particular pass. This helps to make sure that the network is robust and redundant, and does not rely on any one area to come up with answers.

# %% [markdown]
# ### 3.3.5 [Flatten](https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html)

# %% [markdown]
# Flatten takes the output of one layer which is multidimensional, and flattens it into a one-dimensional array. The output is called a feature vector and will be connected to the final classification layer.

# %% [markdown]
# ### 3.3.6 [Linear](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html)

# %% [markdown]
# We have seen dense linear layers before in our earlier models. Our first dense layer (512 units) takes the feature vector as input and learns which features will contribute to a particular classification. The second dense layer (24 units) is the final classification layer that outputs our prediction.

# %% [markdown]
# ## 3.4 Summarizing the Model

# %% [markdown]
# This may feel like a lot of information, but don't worry. It's not critical that to understand everything right now in order to effectively train convolutional models. Most importantly we know that they can help with extracting useful information from images, and can be used in classification tasks.

# %%
# compile : 모델 성능 최적화
# model = torch.compile(model.to(device))
model = base_model.to(device)
model
# Out:
# Sequential(
#   (0): MyConvBlock(
#     (model): Sequential(
#       (0): Conv2d(1, 25, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0, inplace=False)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (1): MyConvBlock(
#     (model): Sequential(
#       (0): Conv2d(25, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.2, inplace=False)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (2): MyConvBlock(
#     (model): Sequential(
#       (0): Conv2d(50, 75, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(75, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0, inplace=False)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (3): Flatten(start_dim=1, end_dim=-1)
#   (4): Linear(in_features=675, out_features=512, bias=True)
#   (5): Dropout(p=0.3, inplace=False)
#   (6): ReLU()
#   (7): Linear(in_features=512, out_features=24, bias=True)
# )

# %% [markdown]
# Since the problem we are trying to solve is still the same (classifying ASL images), we will continue to use the same `loss_function` and `accuracy` metric.

# %%
loss_function = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters())

# %%
# def get_batch_accuracy(output, y, N):
#     pred = output.argmax(dim=1, keepdim=True)
#     correct = pred.eq(y.view_as(pred)).sum().item()
#     return correct / N

# %% [markdown]
# ## Data Augmentation

# %%
random_transforms = transforms.Compose([
    transforms.RandomRotation(5),
    transforms.RandomResizedCrop((IMG_WIDTH, IMG_HEIGHT), scale=(.9, 1), ratio=(1, 1)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=.2, contrast=.5)
])

# %% [markdown]
# ### 3.5 Training the Model

# %% [markdown]
# Despite the very different model architecture, the training looks exactly the same.

# %%
train_loss, train_accuracy = [],[]

def train():
    running_loss = 0
    running_accuracy = 0

    model.train()
    for x, y in train_loader: # x, y는 batch 단위(32개씩)로 처리
        output = model(random_transforms(x))
        optimizer.zero_grad()
        batch_loss = loss_function(output, y) # batch_loss는 32개 batch의 평균오차
        batch_loss.backward()
        optimizer.step()

        running_loss += batch_loss.item() * x.size(0)  # x.size(0) : BATCH SIZE
        
        pred = output.argmax(dim=1, keepdim=True)
        running_accuracy += pred.eq(y.view_as(pred)).sum().item()
    
    
    loss = running_loss / train_N   
    accuracy = running_accuracy / train_N
    ######
    train_loss.append(loss)
    train_accuracy.append(accuracy)
    ######

    print('Train - Loss: {:.4f} Accuracy: {:.4f}'.format(loss, accuracy))

# %%
valid_loss, valid_accuracy = [],[]
y_trues, y_preds = [],[]

def validate():
    running_loss = 0
    running_accuracy = 0
    
    # y_trues = []
    # y_preds = []

    model.eval()
    with torch.no_grad():
        for x, y in valid_loader:
            output = model(x)

            running_loss += loss_function(output, y).item() * x.size(0)
            
            pred = output.argmax(dim=1, keepdim=True)
            running_accuracy += pred.eq(y.view_as(pred)).sum().item()
            
            # 정답과 예측을 리스트에 저장
            y_trues.extend(y.cpu().numpy().tolist())
            y_preds.extend(pred.cpu().numpy().tolist())
            
    
    loss = running_loss / valid_N   
    accuracy = running_accuracy / valid_N
    ######
    valid_loss.append(loss)
    valid_accuracy.append(accuracy)
    ######
    print('Valid - Loss: {:.4f} Accuracy: {:.4f}'.format(loss, accuracy))

# %%
epochs = 10

for epoch in range(epochs):
    print('Epoch: {}'.format(epoch))
    train()
    validate()
    print()
# Out:
# Epoch: 0
# Train - Loss: 0.7858 Accuracy: 0.7430
# Valid - Loss: 0.2293 Accuracy: 0.9285
#
# Epoch: 1
# Train - Loss: 0.1290 Accuracy: 0.9592
# Valid - Loss: 0.1271 Accuracy: 0.9550
#
# Epoch: 2
# Train - Loss: 0.0691 Accuracy: 0.9780
# Valid - Loss: 0.0933 Accuracy: 0.9693
#
# Epoch: 3
# Train - Loss: 0.0500 Accuracy: 0.9836
# Valid - Loss: 0.1073 Accuracy: 0.9593
#
# Epoch: 4
# Train - Loss: 0.0366 Accuracy: 0.9885
# Valid - Loss: 0.0438 Accuracy: 0.9848
#
# Epoch: 5
# Train - Loss: 0.0349 Accuracy: 0.9884
# Valid - Loss: 0.0871 Accuracy: 0.9732
#
# Epoch: 6
# Train - Loss: 0.0304 Accuracy: 0.9897
# Valid - Loss: 0.0834 Accuracy: 0.9728
#
# Epoch: 7
# Train - Loss: 0.0297 Accuracy: 0.9900
# Valid - Loss: 0.1702 Accuracy: 0.9518
#
# Epoch: 8
# Train - Loss: 0.0267 Accuracy: 0.9915
# Valid - Loss: 0.0638 Accuracy: 0.9819
#
# Epoch: 9
# Train - Loss: 0.0189 Accuracy: 0.9940
# Valid - Loss: 0.1579 Accuracy: 0.9639

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.title('Loss')
plt.plot(train_loss, label = 'train loss')
plt.plot(valid_loss, label = 'validation loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.title('Accuracy')
plt.plot(train_accuracy, label = 'train accuracy')
plt.plot(valid_accuracy, label = 'validation accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_trues, y_preds)

# 전체 크기를 작게 고정
fig, ax = plt.subplots(figsize=(7, 6))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    cbar=True,
    linewidths=0,
    linecolor=None,
    annot_kws={'fontsize': 8},  # 숫자 폰트 크기 축소
    square=True,
    ax=ax
)

ax.set_title('Confusion Matrix', pad=12, fontsize=12)
ax.set_xlabel('Predicted Label', labelpad=10, fontsize=10)
ax.set_ylabel('True Label', labelpad=10, fontsize=10)

ax.xaxis.set_ticklabels(ax.xaxis.get_ticklabels(), rotation=0, fontsize=9)
ax.yaxis.set_ticklabels(ax.yaxis.get_ticklabels(), rotation=0, fontsize=9)

# tight_layout으로 여백 최적화
plt.tight_layout(pad=1.0)

plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_trues, y_preds, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9342    1.0000    0.9660      3310
#            1     0.9926    1.0000    0.9963      4320
#            2     0.9968    0.9981    0.9974      3100
#            3     0.9962    0.9669    0.9814      2450
#            4     0.9794    0.9936    0.9864      4980
#            5     0.9848    1.0000    0.9924      2470
#            6     0.9435    0.9118    0.9274      3480
#            7     0.9686    0.9690    0.9688      4360
#            8     0.9430    0.9830    0.9626      2880
#            9     0.9202    0.9927    0.9551      3310
#           10     0.9543    1.0000    0.9766      2090
#           11     0.9676    0.9013    0.9332      3940
#           12     0.8894    0.8983    0.8938      2910
#           13     0.9976    0.9980    0.9978      2460
#           14     0.9264    0.9937    0.9588      3470
#           15     0.9874    1.0000    0.9936      1640
#           16     0.9565    0.9313    0.9437      1440
#           17     0.9750    0.9366    0.9554      2460
#           18     0.9478    0.8423    0.8920      2480
#           19     0.9832    0.9444    0.9634      2660
#           20     0.9454    0.9306    0.9380      3460
#           21     0.9221    1.0000    0.9595      2060
#           22     0.9493    0.9536    0.9514      2670
#           23     0.9920    0.8952    0.9411      3320
#
#     accuracy                         0.9602     71720
#    macro avg     0.9606    0.9600    0.9597     71720
# weighted avg     0.9609    0.9602    0.9599     71720

# %%
torch.save(model, 'asl_model_no_state.pth')

# %%
loaded_model = torch.load('asl_model_no_state.pth')
loaded_model
# Out:
# Sequential(
#   (0): MyConvBlock(
#     (model): Sequential(
#       (0): Conv2d(1, 25, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0, inplace=False)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (1): MyConvBlock(
#     (model): Sequential(
#       (0): Conv2d(25, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.2, inplace=False)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (2): MyConvBlock(
#     (model): Sequential(
#       (0): Conv2d(50, 75, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(75, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0, inplace=False)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (3): Flatten(start_dim=1, end_dim=-1)
#   (4): Linear(in_features=675, out_features=512, bias=True)
#   (5): Dropout(p=0.3, inplace=False)
#   (6): ReLU()
#   (7): Linear(in_features=512, out_features=24, bias=True)
# )

# %% [markdown]
# ## Prediction

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def show_image(image_path):
    image = mpimg.imread(image_path)
    plt.imshow(image, cmap='gray')

# %%
show_image('asl_images/b.png')

# %%
# Scaling the Images
image = tv_io.read_image('asl_images/b.png', tv_io.ImageReadMode.GRAY)
image, image.shape
# Out:
# (tensor([[[247, 223, 178,  ..., 223, 231, 238],
#           [245, 221, 178,  ..., 213, 223, 232],
#           [244, 220, 177,  ..., 204, 217, 228],
#           ...,
#           [247, 243, 238,  ..., 223, 231, 238],
#           [249, 246, 243,  ..., 232, 238, 243],
#           [250, 248, 246,  ..., 240, 243, 246]]], dtype=torch.uint8),
#  torch.Size([1, 184, 186]))

# %%
IMG_WIDTH = 28
IMG_HEIGHT = 28

# PIL 이미지를 바로 텐서로 바꾸고 싶다면 → ToTensor() 사용
# 이미 텐서인 이미지를 float32로 바꾸고 싶다면 → ToDtype() 사용

preprocess_trans = transforms.Compose([
    transforms.ToDtype(torch.float32, scale=True), # Converts [0, 255] to [0, 1]
    transforms.Resize((IMG_WIDTH, IMG_HEIGHT)),
    transforms.Grayscale()  # From Color to Gray
])

# %%
processed_image = preprocess_trans(image)
processed_image, processed_image.shape
# Out:
# (tensor([[[0.6960, 0.6279, 0.6348, 0.6493, 0.6584, 0.6599, 0.6638, 0.6630,
#            0.6652, 0.6677, 0.6711, 0.6696, 0.6661, 0.6677, 0.7103, 0.6559,
#            0.6369, 0.6507, 0.6464, 0.6379, 0.6293, 0.6216, 0.6139, 0.6074,
#            0.5984, 0.5895, 0.5836, 0.6977],
#           [0.7013, 0.6388, 0.6480, 0.6578, 0.6647, 0.6687, 0.6709, 0.6734,
#            0.6746, 0.6794, 0.6814, 0.6784, 0.6902, 0.6801, 0.7648, 0.6606,
#            0.5610, 0.6348, 0.6418, 0.6509, 0.6417, 0.6308, 0.6252, 0.6197,
#            0.6095, 0.6007, 0.5923, 0.6773],
#           [0.7061, 0.6479, 0.6588, 0.6668, 0.6743, 0.6811, 0.6845, 0.6848,
#            0.6872, 0.6898, 0.6913, 0.6909, 0.7671, 0.6833, 0.6945, 0.6803,
#            0.4720, 0.6061, 0.5686, 0.6548, 0.6566, 0.6471, 0.6380, 0.6273,
#            0.6198, 0.6124, 0.6078, 0.6837],
#           [0.7165, 0.6603, 0.6699, 0.6770, 0.6821, 0.6880, 0.6959, 0.7001,
#            0.7027, 0.7014, 0.7009, 0.7041, 0.8257, 0.6885, 0.6387, 0.7202,
#            0.4938, 0.6614, 0.5266, 0.6351, 0.6649, 0.6595, 0.6516, 0.6407,
#            0.6298, 0.6250, 0.6173, 0.6882],
#           [0.7256, 0.6709, 0.6799, 0.6854, 0.6910, 0.6969, 0.7043, 0.7103,
#            0.7102, 0.7125, 0.7133, 0.7139, 0.8611, 0.7188, 0.6335, 0.7608,
#            0.5303, 0.6766, 0.5499, 0.6246, 0.6762, 0.6699, 0.6645, 0.6554,
#            0.6432, 0.6351, 0.6240, 0.6924],
#           [0.7330, 0.6805, 0.6897, 0.6953, 0.7027, 0.7094, 0.7154, 0.7206,
#            0.7205, 0.7473, 0.7414, 0.6798, 0.8693, 0.7476, 0.5998, 0.7269,
#            0.5397, 0.7189, 0.6083, 0.6100, 0.6883, 0.6822, 0.6731, 0.6665,
#            0.6588, 0.6521, 0.6393, 0.6989],
#           [0.7381, 0.6909, 0.7028, 0.7075, 0.7144, 0.7201, 0.7251, 0.7277,
#            0.7299, 0.7945, 0.7620, 0.6435, 0.8501, 0.7202, 0.5661, 0.6856,
#            0.5410, 0.7322, 0.6136, 0.5906, 0.7007, 0.6934, 0.6836, 0.6775,
#            0.6707, 0.6633, 0.6509, 0.7029],
#           [0.7454, 0.7010, 0.7137, 0.7207, 0.7251, 0.7304, 0.7372, 0.7406,
#            0.7431, 0.8278, 0.7804, 0.6528, 0.8622, 0.7322, 0.5645, 0.7076,
#            0.5461, 0.7335, 0.6120, 0.5866, 0.7123, 0.7053, 0.6987, 0.6888,
#            0.6808, 0.6742, 0.6646, 0.7099],
#           [0.7548, 0.7075, 0.7196, 0.7268, 0.7351, 0.7442, 0.7504, 0.7523,
#            0.7529, 0.8489, 0.8071, 0.6684, 0.8756, 0.7723, 0.5502, 0.6870,
#            0.5366, 0.7457, 0.6330, 0.6015, 0.7237, 0.7172, 0.7115, 0.7009,
#            0.6905, 0.6835, 0.6765, 0.7163],
#           [0.7651, 0.7217, 0.7307, 0.7373, 0.7441, 0.7520, 0.7572, 0.7596,
#            0.7575, 0.8611, 0.7932, 0.6405, 0.8541, 0.7321, 0.4840, 0.6115,
#            0.4894, 0.7340, 0.6253, 0.6107, 0.7308, 0.7246, 0.7194, 0.7067,
#            0.6986, 0.6930, 0.6829, 0.7200],
#           [0.7702, 0.7298, 0.7419, 0.7504, 0.7515, 0.7571, 0.7627, 0.7644,
#            0.7634, 0.8619, 0.8145, 0.6129, 0.7897, 0.6791, 0.5235, 0.5689,
#            0.5194, 0.6971, 0.5656, 0.6145, 0.7395, 0.7311, 0.7311, 0.7198,
#            0.7063, 0.6992, 0.6877, 0.7236],
#           [0.7731, 0.7333, 0.7501, 0.7598, 0.7619, 0.7667, 0.7735, 0.7755,
#            0.7703, 0.8683, 0.8244, 0.6060, 0.7601, 0.7788, 0.6607, 0.6570,
#            0.7361, 0.6433, 0.4766, 0.6062, 0.7470, 0.7415, 0.7397, 0.7300,
#            0.7173, 0.7084, 0.7005, 0.7292],
#           [0.7803, 0.7425, 0.7562, 0.7661, 0.7716, 0.7772, 0.7853, 0.7869,
#            0.7865, 0.8939, 0.8366, 0.7290, 0.7087, 0.6765, 0.7185, 0.7146,
#            0.7481, 0.6516, 0.4623, 0.5844, 0.7550, 0.7527, 0.7436, 0.7345,
#            0.7249, 0.7188, 0.7139, 0.7344],
#           [0.7857, 0.7519, 0.7614, 0.7720, 0.7795, 0.7852, 0.7930, 0.7927,
#            0.8062, 0.9326, 0.8685, 0.7303, 0.6154, 0.5670, 0.6339, 0.6400,
#            0.7295, 0.7404, 0.5492, 0.5713, 0.7595, 0.7567, 0.7497, 0.7437,
#            0.7353, 0.7283, 0.7236, 0.7384],
#           [0.7962, 0.7608, 0.7683, 0.7789, 0.7867, 0.7942, 0.7976, 0.7982,
#            0.8256, 0.9599, 0.8613, 0.6690, 0.5525, 0.5470, 0.5942, 0.6353,
#            0.8142, 0.8427, 0.6780, 0.5950, 0.7625, 0.7631, 0.7567, 0.7536,
#            0.7469, 0.7327, 0.7221, 0.7353],
#           [0.7973, 0.7658, 0.7763, 0.7849, 0.7925, 0.8019, 0.8045, 0.8049,
#            0.8447, 0.9687, 0.8495, 0.6453, 0.5374, 0.5607, 0.6472, 0.7540,
#            0.8591, 0.8658, 0.7467, 0.5874, 0.7299, 0.7715, 0.7537, 0.7251,
#            0.7073, 0.6471, 0.5496, 0.6368],
#           [0.7989, 0.7678, 0.7793, 0.7858, 0.7936, 0.7991, 0.8039, 0.8086,
#            0.8519, 0.9733, 0.8659, 0.6545, 0.5515, 0.5869, 0.6860, 0.8312,
#            0.8993, 0.8434, 0.7308, 0.5500, 0.6788, 0.7556, 0.5820, 0.4817,
#            0.4493, 0.3947, 0.3452, 0.5655],
#           [0.7989, 0.7647, 0.7767, 0.7855, 0.7954, 0.7989, 0.8028, 0.8095,
#            0.8439, 0.9725, 0.8849, 0.6788, 0.5622, 0.6192, 0.7184, 0.8763,
#            0.9149, 0.8298, 0.6990, 0.5179, 0.6845, 0.6413, 0.4226, 0.3916,
#            0.3717, 0.3501, 0.3414, 0.5592],
#           [0.8004, 0.7709, 0.7811, 0.7876, 0.7997, 0.8057, 0.8108, 0.8123,
#            0.8408, 0.9708, 0.9007, 0.7175, 0.5854, 0.6416, 0.7505, 0.9147,
#            0.9114, 0.8024, 0.6537, 0.5100, 0.6431, 0.4907, 0.3608, 0.3266,
#            0.3042, 0.2913, 0.3058, 0.5493],
#           [0.8028, 0.7784, 0.7892, 0.7968, 0.8067, 0.8115, 0.8168, 0.8176,
#            0.8394, 0.9602, 0.9093, 0.7519, 0.6211, 0.6364, 0.7657, 0.9326,
#            0.8834, 0.7556, 0.6154, 0.4715, 0.4537, 0.3496, 0.2947, 0.2483,
#            0.2108, 0.1780, 0.2274, 0.5359],
#           [0.8084, 0.7843, 0.7959, 0.8028, 0.8100, 0.8145, 0.8210, 0.8248,
#            0.8378, 0.9428, 0.9149, 0.7884, 0.6723, 0.6375, 0.7476, 0.9119,
#            0.8402, 0.7004, 0.5736, 0.4211, 0.3561, 0.3111, 0.2596, 0.2185,
#            0.2065, 0.1963, 0.2376, 0.5366],
#           [0.8119, 0.7835, 0.7957, 0.8038, 0.8107, 0.8182, 0.8257, 0.8293,
#            0.8348, 0.9140, 0.9279, 0.8250, 0.7242, 0.6641, 0.7005, 0.8559,
#            0.7827, 0.6306, 0.5190, 0.3836, 0.3422, 0.3344, 0.2802, 0.2049,
#            0.1894, 0.2016, 0.2194, 0.5103],
#           [0.7556, 0.7140, 0.7286, 0.7326, 0.7406, 0.7492, 0.7635, 0.7719,
#            0.7784, 0.8478, 0.9378, 0.8447, 0.7514, 0.6784, 0.6332, 0.7672,
#            0.7035, 0.5411, 0.4454, 0.3365, 0.3069, 0.3305, 0.3317, 0.2358,
#            0.1783, 0.1908, 0.2093, 0.4976],
#           [0.5617, 0.4596, 0.4660, 0.4625, 0.4623, 0.4683, 0.4773, 0.4887,
#            0.5028, 0.6108, 0.9405, 0.8575, 0.7469, 0.6421, 0.5607, 0.6235,
#            0.5803, 0.4467, 0.3607, 0.2649, 0.2650, 0.2896, 0.3480, 0.2902,
#            0.1924, 0.1703, 0.1971, 0.4916],
#           [0.5361, 0.4209, 0.4179, 0.4154, 0.4167, 0.4162, 0.4127, 0.4203,
#            0.3978, 0.4286, 0.8714, 0.8004, 0.6628, 0.5521, 0.4909, 0.5096,
#            0.4805, 0.3808, 0.2422, 0.1745, 0.2185, 0.2453, 0.3183, 0.3221,
#            0.2315, 0.1644, 0.1780, 0.4908],
#           [0.5491, 0.4269, 0.4296, 0.4264, 0.4323, 0.4326, 0.4330, 0.4380,
#            0.3963, 0.2552, 0.6048, 0.6484, 0.5450, 0.4699, 0.4480, 0.4281,
#            0.3992, 0.2762, 0.1146, 0.1069, 0.1878, 0.2146, 0.2748, 0.3332,
#            0.2809, 0.1870, 0.1570, 0.4802],
#           [0.5653, 0.4458, 0.4453, 0.4379, 0.4472, 0.4517, 0.4541, 0.4578,
#            0.4619, 0.3272, 0.4061, 0.5462, 0.5046, 0.4474, 0.4330, 0.3681,
#            0.3074, 0.1693, 0.0934, 0.1482, 0.2546, 0.2427, 0.2538, 0.3271,
#            0.3277, 0.2437, 0.1819, 0.4824],
#           [0.7822, 0.6822, 0.6749, 0.6725, 0.6757, 0.6784, 0.6790, 0.6801,
#            0.6824, 0.6579, 0.6527, 0.6838, 0.6824, 0.6756, 0.6680, 0.6401,
#            0.6141, 0.5686, 0.5584, 0.5850, 0.6220, 0.6086, 0.6050, 0.6293,
#            0.6379, 0.6134, 0.5933, 0.7271]]]),
#  torch.Size([1, 28, 28]))

# %%
plot_image = F.to_pil_image(processed_image)
plt.imshow(plot_image, cmap='gray')

# %%
batched_image = processed_image.unsqueeze(0)
batched_image.shape
# Out:
# torch.Size([1, 1, 28, 28])

# %%
batched_image_gpu = batched_image.to(device)
batched_image_gpu.device
# Out:
# device(type='cuda', index=0)

# %%
output = loaded_model(batched_image_gpu)
output
# Out:
# tensor([[-15.4772,   6.2517,  -6.9374, -14.0814,  -2.0442,  -4.9245,  -4.3687,
#          -13.4870,  -3.7862,  -5.8354,  -0.1401,  -9.2118,  -6.6449, -20.9952,
#           -7.6223, -12.4126, -13.7911, -20.1261, -11.0892,  -0.3296,  -9.6669,
#            0.3157,  -7.2777, -13.2216]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)

# %%
prediction = output.argmax(dim=1).item()
prediction
# Out:
# 1

# %% [markdown]
# ### 3.5.1 Discussion of Results

# %% [markdown]
# It looks like this model is significantly improved! The training accuracy is very high, and the validation accuracy has improved as well. This is a great result, as all we had to do was swap in a new model.
#
# You may have noticed the validation accuracy jumping around. This is an indication that our model is still not generalizing perfectly. Fortunately, there's more that we can do. Let's talk about it in the next lecture.

# %% [markdown]
# ## 3.6 Summary

# %% [markdown]
# In this section, we utilized several new kinds of layers to implement a CNN, which performed better than the more simple model used in the last section. Hopefully the overall process of creating and training a model with prepared data is starting to become even more familiar.

# %% [markdown]
# ### 3.6.2 Next

# %% [markdown]
# In the last several sections you have focused on the creation and training of models. In order to further improve performance, you will now turn your attention to *data augmentation*, a collection of techniques that will allow your models to train on more and better data than what you might have originally at your disposal.

# %% [markdown]
# ![DLI_Header.png](data:image/png;base64,...)
